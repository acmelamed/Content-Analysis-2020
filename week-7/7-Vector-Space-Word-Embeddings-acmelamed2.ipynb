# %% [markdown]
# # Week 7 - Vector Space Word Embeddings
#
# This week, we build on last week's topic modeling techniques by taking a text corpus we have developed, specifying an underlying number of dimensions, and training a model with a neural network auto-encoder (one of Google's word2vec  algorithms) that best describes corpus words in their local linguistic contexts, and exploring their locations in the resulting space to learn about the discursive culture that produced them. Documents here are represented as densely indexed locations in dimensions, rather than sparse mixtures of topics (as in LDA topic modeling), so that distances between those documents (and words) are consistently superior, though they require the full vector of dimension loadings (rather than just a few selected topic loadings) to describe. We will explore these spaces to understand complex, semantic relationships between words, index documents with descriptive words, identify the likelihood that a given document would have been produced by a given vector model, and explore how semantic categories can help us understand the cultures that produced them.
#
# For this notebook we will be using the following packages

# %%
#All these packages need to be installed from pip
import gensim#For word2vec, etc
import requests #For downloading our datasets
import lucem_illud_2020

import numpy as np #For arrays
import pandas #Gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import seaborn #Makes the graphics look nicer
import sklearn.metrics.pairwise #For cosine similarity
import sklearn.manifold #For T-SNE
import sklearn.decomposition #For PCA

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning
# %matplotlib inline

import os #For looking through files
import os.path #For managing file paths
# Out:
# C:\Users\acmel\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project using at least two different specification of `word2vec`, and visualize them each with two separate visualization layout specifications (e.g., TSNE, PCA). Then interrogate critical word vectors within your corpus in terms of the most similar words, analogies, and other additions and subtractions that reveal the structure of similarity and difference within your semantic space. What does this pattern reveal about the semantic organization of words in your corpora? Which estimation and visualization specification generate the most insight and appear the most robustly supported and why?
#
# <span style="color:red">***Stretch***: Explore different vector calculations beyond addition and subtraction, such as multiplication, division or some other function. What does this exploration reveal about the semantic structure of your corpus?

# %% [markdown]
# The corpora for this assignment and the accompanying presentation was built from the most recent 2-10 HITs published first 10 Requesters who appeared on the first 2 pages of the mTurk HITs page at 6:13pm 2/20/2020 and had published 2 or more HITs at that point in time.

# %%
def loadDir(targetDir, category):
    allFileNames = os.listdir(targetDir)
    #We need to make them into useable paths and filter out hidden files
    filePaths = [os.path.join(targetDir, fname) for fname in allFileNames if fname[0] != '.']

    #The dict that will become the DataFrame
    hitsDict = {
        'Requester' : [category] * len(filePaths),
        'filePath' : [],
        'text' : [],
    }

    for fPath in filePaths:
        with open(fPath) as f:
            hitsDict['text'].append(f.read())
            hitsDict['filePath'].append(fPath)

    return pandas.DataFrame(hitsDict)

# %%
dataDir = r'C:\Users\acmel\OneDrive - The University of Chicago\SOCI 40133\CorporaV1'

hitsDF = pandas.DataFrame()

for reqName in [d for d in os.listdir(dataDir) if d[0] != '.']:
    reqPath = os.path.join(dataDir, reqName)
    hitsDF = hitsDF.append(loadDir(reqPath, reqName), ignore_index = True)

hitsDF[:100:1]
# Out:
#             Requester                                           filePath  \
# 0    Bailey OSullivan  C:\Users\acmel\OneDrive - The University of Ch...
# 1    Bailey OSullivan  C:\Users\acmel\OneDrive - The University of Ch...
# 2    Bailey OSullivan  C:\Users\acmel\OneDrive - The University of Ch...
# 3    Content Research  C:\Users\acmel\OneDrive - The University of Ch...
# 4    Content Research  C:\Users\acmel\OneDrive - The University of Ch...
# 5       HYUNSUK CHUNG  C:\Users\acmel\OneDrive - The University of Ch...
# 6       HYUNSUK CHUNG  C:\Users\acmel\OneDrive - The University of Ch...
# 7     Jesse D Crosson  C:\Users\acmel\OneDrive - The University of Ch...
# 8     Jesse D Crosson  C:\Users\acmel\OneDrive - The University of Ch...
# 9              Jiaxin  C:\Users\acmel\OneDrive - The University of Ch...
# 10             Jiaxin  C:\Users\acmel\OneDrive - The University of Ch...
# 11      ML Researcher  C:\Users\acmel\OneDrive - The University of Ch...
# 12      ML Researcher  C:\Users\acmel\OneDrive - The University of Ch...
# 13      ML Researcher  C:\Users\acmel\OneDrive - The University of Ch...
# 14        NLUResearch  C:\Users\acmel\OneDrive - The University of Ch...
# 15        NLUResearch  C:\Users\acmel\OneDrive - The University of Ch...
# 16       Oliver Boyne  C:\Users\acmel\OneDrive - The University of Ch...
# 17       Oliver Boyne  C:\Users\acmel\OneDrive - The University of Ch...
# 18              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 19              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 20              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 21              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 22              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 23              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 24              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 25              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 26              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 27              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 28  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 29  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 30  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 31  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 32  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 33  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 34  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 35  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 36  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 37  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
# 38      xlab research  C:\Users\acmel\OneDrive - The University of Ch...
# 39      xlab research  C:\Users\acmel\OneDrive - The University of Ch...
#
#                                                  text
# 0   Bailey O'Sullivan\nContact Info Search\n1,360\...
# 1   Bailey O'Sullivan\nContact Info Search\n303\n$...
# 2   \nBailey O'Sullivan\nContact Info Search\n9\n$...
# 3   Content Research\nClean Up How-To Questions\n4...
# 4   Content Research\nCategorize User Reviews\n1\n...
# 5   HYUNSUK CHUNG\nWrite the words shown in an ima...
# 6   \nHYUNSUK CHUNG\nWrite the words shown in an i...
# 7   Jesse D. Crosson\nCongressional press release ...
# 8   Jesse D. Crosson\nCongressional press release ...
# 9   Jiaxin\nDo these two questions have the same m...
# 10  Jiaxin\nParaphrase machine-generated questions...
# 11  ML Researcher\nHybrid Table/Text Question Answ...
# 12  ML Researcher\nVerify an interpretation of a s...
# 13  ML Researcher\nHybrid Table/Text Question Answ...
# 14  NLUResearch\nExplain a Story regular largescal...
# 15  NLUResearch\nExplain a Story regular largescal...
# 16  Oliver Boyne\nLabel dog keypoints\n1,831\n$0.0...
# 17  Oliver Boyne\nSegment the dog in each image\n1...
# 18  Panel\nExtract purchased items from a shopping...
# 19  Panel\nExtract purchased items from a shopping...
# 20  Panel\nExtract purchased items from a shopping...
# 21  Panel\nExtract purchased items from a shopping...
# 22  \nPanel\nExtract purchased items from a shoppi...
# 23  Panel\nClassify Receipt\n113\n$0.03\n9s ago\nP...
# 24  Panel\nExtract purchased items from a shopping...
# 25  Panel\nExtract purchased items from a shopping...
# 26  Panel\nExtract purchased items from a shopping...
# 27  Panel\nExtract purchased items from a shopping...
# 28  Shopping Receipts\nExtract Data From Shopping ...
# 29  Shopping Receipts\nExtract Data From Shopping ...
# 30  Shopping Receipts\nExtract Data From Shopping ...
# 31  Shopping Receipts\nExtract Data From Shopping ...
# 32  Shopping Receipts\nExtract Data From Shopping ...
# 33  Shopping Receipts\nExtract Data From Shopping ...
# 34  Shopping Receipts\nExtract Data From Shopping ...
# 35  Shopping Receipts\nExtract Data From Shopping ...
# 36  Shopping Receipts\nExtract Data From Shopping ...
# 37  \nShopping Receipts\nExtract Data From Shoppin...
# 38  xlab research\nWrite captions about photoshopp...
# 39  xlab research\nEvaluate the helpfulness of wri...

# %%
#Apply our functions, notice each row is a list of lists now
hitsDF['tokenized_sents'] = hitsDF['text'].apply(lambda x: [lucem_illud_2020.word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x)])
hitsDF['normalized_sents'] = hitsDF['tokenized_sents'].apply(lambda x: [lucem_illud_2020.normalizeTokens(s, lemma=False) for s in x])

hitsDF[:100:10]
# Out:
#             Requester                                           filePath  \
# 0    Bailey OSullivan  C:\Users\acmel\OneDrive - The University of Ch...
# 10             Jiaxin  C:\Users\acmel\OneDrive - The University of Ch...
# 20              Panel  C:\Users\acmel\OneDrive - The University of Ch...
# 30  Shopping Receipts  C:\Users\acmel\OneDrive - The University of Ch...
#
#                                                  text  \
# 0   Bailey O'Sullivan\nContact Info Search\n1,360\...
# 10  Jiaxin\nParaphrase machine-generated questions...
# 20  Panel\nExtract purchased items from a shopping...
# 30  Shopping Receipts\nExtract Data From Shopping ...
#
#                                       tokenized_sents  \
# 0   [[Bailey, O'Sullivan], [Contact, Info, Search]...
# 10  [[Jiaxin], [Paraphrase, machine, generated, qu...
# 20  [[Panel, Extract, purchased, items, from, a, s...
# 30  [[Shopping, Receipts, Extract, Data, From, Sho...
#
#                                      normalized_sents
# 0   [[bailey, o'sullivan], [contact, info, search]...
# 10  [[jiaxin], [paraphrase, machine, generated, qu...
# 20  [[panel, extract, purchased, items, shopping, ...
# 30  [[shopping, receipts, extract, data, shopping,...

# %% [markdown]
# Word2Vec starts here

# %%
hitsW2V = gensim.models.word2vec.Word2Vec(hitsDF['normalized_sents'].sum())

# %%
hitsW2V['image']
# %%
hitsW2V.wv.index2word
# Out:
# ['shopping',
#  'receipt',
#  '$',
#  'preview',
#  'description',
#  'time',
#  'allotted',
#  'min',
#  'ago',
#  'extract',
#  'items',
#  'qualify',
#  'image',
#  'data',
#  'purchased',
#  'write',
#  'panel',
#  'receipts',
#  'readable',
#  'quantities',
#  'blackened',
#  'm',
#  'transcribe',
#  'words',
#  'question',
#  'story',
#  'contact',
#  'info',
#  'find',
#  'email',
#  'questions',
#  'amounts',
#  'grocery',
#  'table',
#  'item']

# %%
hitsW2V.most_similar('image')
# Out:
# [('find', 0.12820705771446228),
#  ('ago', 0.0943690687417984),
#  ('grocery', 0.0799008160829544),
#  ('panel', 0.0741114467382431),
#  ('min', 0.07328750193119049),
#  ('qualify', 0.06959003210067749),
#  ('items', 0.06425068527460098),
#  ('quantities', 0.06253580749034882),
#  ('write', 0.06161879375576973),
#  ('amounts', 0.05750836431980133)]

# %%
hitsW2V.most_similar('find')
# Out:
# [('question', 0.27656587958335876),
#  ('min', 0.23860038816928864),
#  ('extract', 0.14520391821861267),
#  ('image', 0.12820705771446228),
#  ('item', 0.1230192631483078),
#  ('time', 0.10253018885850906),
#  ('m', 0.10174776613712311),
#  ('contact', 0.09382875263690948),
#  ('preview', 0.09259270876646042),
#  ('story', 0.07812830805778503)]

# %%
hitsW2V.most_similar('transcribe')
# Out:
# [('min', 0.21765218675136566),
#  ('allotted', 0.11665596812963486),
#  ('words', 0.11570071429014206),
#  ('time', 0.10167400538921356),
#  ('info', 0.08545220643281937),
#  ('find', 0.05904669314622879),
#  ('questions', 0.05738586187362671),
#  ('receipt', 0.04963168874382973),
#  ('table', 0.029987188056111336),
#  ('blackened', 0.025657443329691887)]

# %%
hitsW2V.most_similar('words')
# Out:
# [('time', 0.26957374811172485),
#  ('purchased', 0.1534736156463623),
#  ('story', 0.150374636054039),
#  ('transcribe', 0.11570071429014206),
#  ('items', 0.031563445925712585),
#  ('shopping', 0.018973156809806824),
#  ('write', 0.018951203674077988),
#  ('question', 0.012121289037168026),
#  ('item', 0.0026301294565200806),
#  ('image', 0.001462545245885849)]

# %%
hitsW2V.most_similar(
    positive=['image','find'], 
    negative=['transcribe','words']
)
# Out:
# [('extract', 0.18462009727954865),
#  ('m', 0.1431097388267517),
#  ('contact', 0.13562709093093872),
#  ('question', 0.1350313425064087),
#  ('amounts', 0.13064219057559967),
#  ('email', 0.11675072461366653),
#  ('panel', 0.10065481066703796),
#  ('qualify', 0.09521669149398804),
#  ('min', 0.0948956087231636),
#  ('data', 0.09396128356456757)]

# %% [markdown]
# These words (W) are the best results for the semantic equation of X+Y-Z=W where X=image and Z=transcribe+words.  The purpose of this test is to attempt an analysis of which terms appear most frequently in HITs assigned for the processing of image data but which do not involve the transcription of written words.  Hypothetically, given what is known about the types of HIT work involving image analysis generally exist, we can infer that words (W) are those which are most frequently associated with HITs assigned for the purpose of training image-based ML as opposed to those for transcribing scanned texts -- another common form of image-based HIT.

# %% [markdown]
# That said, the coefficients which appear here are small, indicating that there might not be a strong distinction between these two hypothetical categories of HITs as represented in the dataset.

# %%
hitsW2V.save("hitsWord2Vec")
# Out:
# C:\Users\acmel\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
numWords = 50
targetWords = hitsW2V.wv.index2word[:numWords]

# %%
wordsSubMatrix = []
for words in targetWords:
    wordsSubMatrix.append(hitsW2V['image'])
wordsSubMatrix = np.array(wordsSubMatrix)
wordsSubMatrix
# Out:
# array([[ 3.8494461e-03,  4.6031359e-03, -1.8997438e-05, ...,
#         -4.5799920e-03,  3.4788849e-03, -8.7088667e-04],
#        [ 3.8494461e-03,  4.6031359e-03, -1.8997438e-05, ...,
#         -4.5799920e-03,  3.4788849e-03, -8.7088667e-04],
#        [ 3.8494461e-03,  4.6031359e-03, -1.8997438e-05, ...,
#         -4.5799920e-03,  3.4788849e-03, -8.7088667e-04],
#        ...,
#        [ 3.8494461e-03,  4.6031359e-03, -1.8997438e-05, ...,
#         -4.5799920e-03,  3.4788849e-03, -8.7088667e-04],
#        [ 3.8494461e-03,  4.6031359e-03, -1.8997438e-05, ...,
#         -4.5799920e-03,  3.4788849e-03, -8.7088667e-04],
#        [ 3.8494461e-03,  4.6031359e-03, -1.8997438e-05, ...,
#         -4.5799920e-03,  3.4788849e-03, -8.7088667e-04]], dtype=float32)

# %%
pcaWords = sklearn.decomposition.PCA(n_components = 10).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data)

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# The word cloud validates to a certain extent the previously mentioned hypothesis that HITs which involve "image[s]" are associated with both "words" and "find" -- implying that there are multiple types of analysis being performed involving either scanned writing or visual objects.  However, the distance of "transcribe" from "image" here discounts that hypothesis somewhat, despite other word-associated terms like "receipt" and "readable" remaining relative close to it.

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project using `doc2vec`, and explore the relationship between different documents and the word vectors you analyzed in the last exercise. Consider the most similar words to critical documents, analogies (doc _x_ + word _y_), and other additions and subtractions that reveal the structure of similarity and difference within your semantic space. What does this pattern reveal about the documentary organization of your semantic space?

# %%
hitsmk1DF = pandas.read_csv( r"C:\Users\acmel\OneDrive - The University of Chicago\SOCI 40133\Octoparse\test2.csv", 
    index_col = 0)
hitsmk1DF[:800:100]
# Out:
#                                                                        Title  \
# Requester
# Panel                        Extract purchased items from a shopping receipt
# Anders Friis Marstand      A study of leaders (follow-up survey)(~ 3 minu...
# str11223344                Tell us what this item is - Soft Goods - Batch...
# MODIFI                     Collect data from the 'impressum' section of a...
# Alexandria Powers               Answer a survey about disability perceptions
# Mike                                        14 Short, Silly Yes/No Questions
# Phonology and Reading Lab  Compensation for previous HIT "How the Mind Wo...
# Noah Turk                            Which Conversational Partner is Better?
#
#                            Reward
# Requester
# Panel                      $0.09
# Anders Friis Marstand      $0.80
# str11223344                $0.07
# MODIFI                     $0.08
# Alexandria Powers          $1.05
# Mike                       $0.10
# Phonology and Reading Lab  $0.30
# Noah Turk                  $0.50

# %% [markdown]
# keywords= verbs and instructions

# %%
keywords = ['extract', 'trace', 'create', 'answer', 'seeing', 'clean', 'find',
            'paraphrase', 'write', 'answer', 'label', 'search', 'judge', 
            'tell', 'collect', 'describe', 'talk', 'draw', 'write', 'do', 
            'chat', 'identify', 'evaluate', 'verify', 'rate', 'survey', 
            'upload', 'compare', 'watch', 'record', 'determine', 
            'categorization', 'make', 'provide', 'transcribe', 'help',
           'audit', 'aprender']
keywords
# Out:
# ['extract',
#  'trace',
#  'create',
#  'answer',
#  'seeing',
#  'clean',
#  'find',
#  'paraphrase',
#  'write',
#  'answer',
#  'label',
#  'search',
#  'judge',
#  'tell',
#  'collect',
#  'describe',
#  'talk',
#  'draw',
#  'write',
#  'do',
#  'chat',
#  'identify',
#  'evaluate',
#  'verify',
#  'rate',
#  'survey',
#  'upload',
#  'compare',
#  'watch',
#  'record',
#  'determine',
#  'categorization',
#  'make',
#  'provide',
#  'transcribe',
#  'help',
#  'audit',
#  'aprender']

# %%
hitsmk1DF['tokenized_words'] = hitsmk1DF['Title'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
hitsmk1DF['normalized_words'] = hitsmk1DF['tokenized_words'].apply(lambda x: lucem_illud_2020.normalizeTokens(x, lemma=False))

# %%
taggedDocs = []
for index, row in hitsmk1DF.iterrows():
    #Just doing a simple keyword assignment
    docKeywords = [s for s in keywords if s in row['normalized_words']]
    docKeywords.append(row['Title'])
  #  docKeywords.append(row['doi']) #This lets us extract individual documnets since doi's are unique
    taggedDocs.append(gensim.models.doc2vec.LabeledSentence(words = row['normalized_words'], tags = docKeywords))
hitsmk1DF['TaggedTitle'] = taggedDocs

# %%
hitsmk1DF['TaggedTitle'] = taggedDocs

# %%
hitsmk1D2V = gensim.models.doc2vec.Doc2Vec(hitsmk1DF['TaggedTitle'])
#, vector_size = 100) #Limiting to 100 dimensions

# %%
hitsmk1D2V.docvecs[1]
# Out:
# array([ 9.6535624e-04, -1.1478332e-04,  1.6064256e-03,  2.7235500e-03,
#         3.1064681e-03,  3.0732877e-03,  1.8053842e-03,  2.2169629e-03,
#        -2.7723680e-03, -2.2522770e-03, -3.1567926e-03,  2.9330275e-03,
#         1.3616447e-03, -3.8872976e-03, -3.4540885e-03,  9.6177176e-04,
#         4.3247016e-03,  3.7774094e-03,  8.3050586e-04,  3.9004514e-03,
#        -1.6233580e-04,  2.2058346e-04,  4.2021759e-03, -3.0902063e-03,
#         3.5125676e-03,  1.4555665e-03, -8.9643802e-04, -1.5563359e-03,
#         4.3168650e-03,  1.9421637e-03, -1.6330696e-03,  1.2010824e-03,
#        -4.4868286e-03, -4.2356993e-03,  5.5517320e-04, -7.5842242e-04,
#        -4.1232854e-03,  1.5289991e-03,  3.0441743e-03,  1.2267713e-03,
#        -1.0401420e-03,  9.3531143e-04, -1.9787156e-03, -1.4305293e-03,
#        -5.1709851e-03, -4.4719118e-04, -2.4681620e-03, -4.3908422e-05,
#         1.9133171e-04, -3.1897721e-03,  1.2071019e-03, -2.9970340e-03,
#         3.4749161e-03, -1.4021049e-03,  5.1162420e-03,  1.5874511e-03,
#        -1.0239824e-03,  2.8537733e-03, -3.0488616e-03, -3.7936349e-03,
#        -1.2305161e-03, -5.4735686e-03, -6.4959691e-04, -2.7760735e-03,
#         5.3417617e-03, -2.3801539e-03,  5.2275113e-03, -1.7929454e-03,
# This is another interesting result, implying that "collect" is to "data" as "extract" is to "persona" -- presumabkly, "personal" information of some sort.  To extent that HITs which request that the Worker collect something are connected to data objects, HITs which request that the Worker extract something are connected in the same way to personal information.
#
# From this, we can hypothesize that HITs similarly structure cognitive labor involving both the investigation of individuals' personal information and the gathering of generic information from other sources.
#
# In this, we can see an example of the alienation which digital crowdlabor platforms inflict on individuals by computationally commodifying information.

# %% [markdown]
# HeatMap plots

# %%
keywords = ['extract', 'trace', 'create', 'answer', 'seeing', 'clean', 'find',
            'paraphrase', 'write', 'answer', 'label', 'search', 'judge', 
            'tell', 'collect', 'describe', 'talk', 'draw', 'write', 
            'chat', 'identify', 'evaluate', 'verify', 'rate', 'survey', 
            'upload', 'compare', 'watch', 'record', 'determine', 
            'categorization', 'provide', 'transcribe', 'help',
           'audit', 'aprender']

# %%
heatmapMatrix = []
for tagOuter in keywords:
    column = []
    tagVec = hitsmk1D2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity
                      (tagVec, hitsmk1D2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrix.append(column)
heatmapMatrix = np.array(heatmapMatrix)

# %%
fig, ax = plt.subplots(figsize=(20,20))
hmap = ax.pcolor(heatmapMatrix, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270, size=20)
a = ax.set_xticks(np.arange(heatmapMatrix.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrix.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270, size=20)
a = ax.set_yticklabels(keywords, minor=False, size=20)

# %% [markdown]
# Predictably, the terms "answer" and "tell" are very closely associated with "survey".  More interestingly, "extract" is also associated with both "survey" and "answer".  Building on the previous hypothesis about the relation between "extract" instructions and "personal (data)" we can infer that the primary means of extracting personal data is through surveys issued to mTurk Workers.  This then implies that the personal data being extracted is that of the Workers themselves, further supporting the theory that the Workers are the primary subjects of computationa alienation via crowdsourced data commodification.

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">Construct cells immediately below this that embed documents related to your final project, then generate meaningful semantic dimensions based on your theoretical understanding of the semantic space (i.e., by subtracting semantically opposite word vectors) and project another set of word vectors onto those dimensions. Interpret the meaning of these projections for your analysis. Which of the dimensions you analyze explain the most variation in the projection of your words and why?
#
# <span style="color:red">***Stretch***: Average together multiple antonym pairs to create robust semantic dimensions. How do word projections on these robust dimensions differ from single-pair dimensions?

# %%
#Apply our functions, notice each row is a list of lists now
hitsmk1DF['tokenized_sents'] = hitsmk1DF['Title'].apply(lambda x: [lucem_illud_2020.word_tokenize(s) for s in lucem_illud_2020.sent_tokenize(x)])
hitsmk1DF['normalized_sents'] = hitsmk1DF['tokenized_sents'].apply(lambda x: [lucem_illud_2020.normalizeTokens(s, lemma=False) for s in x])

hitsmk1DF[:100:10]
# Out:
#                                                              Title Reward  \
# Requester
# Panel              Extract purchased items from a shopping receipt  0.09
# celinachan610               Paraphrase machine-generated questions  0.10
# Job Spotter         Extract contact information from a hiring sign  0.03
# xlab research             Write captions about photoshopped images  1.50
# str11223344      Tell us what this item is - General Contents -...  0.07
# Maarten Sap                      Rate the quality of short stories  0.27
# Pinterest        Pinterest - Determine the topical relatedness ...  0.60
# Panel            Extract purchased items from a shopping receip...  0.04
# David Markowitz  Tell us about your experiences in media planni...  0.50
# Panel            Extract purchased items from a shopping receip...  0.02
#
#                                                    tokenized_sents  \
# Requester
# Panel            [[Extract, purchased, items, from, a, shopping...
# celinachan610        [[Paraphrase, machine, generated, questions]]
# Job Spotter      [[Extract, contact, information, from, a, hiri...
# xlab research     [[Write, captions, about, photoshopped, images]]
# str11223344      [[Tell, us, what, this, item, is, General, Con...
# Maarten Sap             [[Rate, the, quality, of, short, stories]]
# Pinterest        [[Pinterest, Determine, the, topical, relatedn...
# Panel            [[Extract, purchased, items, from, a, shopping...
# David Markowitz  [[Tell, us, about, your, experiences, in, medi...
# Panel            [[Extract, purchased, items, from, a, shopping...
#
#                                                   normalized_sents
# Requester
# Panel             [[extract, purchased, items, shopping, receipt]]
# celinachan610        [[paraphrase, machine, generated, questions]]
# Job Spotter        [[extract, contact, information, hiring, sign]]
# xlab research            [[write, captions, photoshopped, images]]
# str11223344            [[tell, item, general, contents, batch, d]]
# Maarten Sap                      [[rate, quality, short, stories]]
# Pinterest        [[pinterest, determine, topical, relatedness, ...
# Panel            [[extract, purchased, items, shopping, receipt...
# David Markowitz  [[tell, experiences, media, planning!(~, minut...
# Panel            [[extract, purchased, items, shopping, receipt...

# %%
hitsmk1W2V = gensim.models.word2vec.Word2Vec(hitsmk1DF['normalized_sents'].sum())

# %%
hitsmk1W2V.wv.syn0
hitsmk1W2V.wv.index2word
# Out:
# ['minutes',
#  'survey',
#  'batch',
#  'd',
#  'tell',
#  'item',
#  'compensation',
#  'hit(~',
#  'hit',
#  'answer',
#  'extract',
#  'health',
#  'data',
#  'shopping',
#  'ages',
#  'mental',
#  'receipt',
#  'items',
#  'veterans',
#  '65)(~',
#  'general',
#  'contents',
#  'study',
#  '$',
#  'chat',
#  'evaluate',
#  'bot',
#  'soft',
#  'goods',
#  '~',
#  'short',
#  'purchased',
#  'task',
#  'question',
#  'find',
#  'image',
#  'information',
#  'website',
#  'questions',
#  'minute',
#  'images',
#  'bonus',
#  'cost',
#  'replace',
#  'summary',
#  'text',
#  'collect',
#  'electronics',
#  'better',
#  'identify',
#  'bounding',
#  'draw',
#  'business',
#  'game',
#  'brands',
#  'ads',
#  'complete',
#  'featured',
#  'banner',
#  'article',
#  'transcribe',
#  'group',
#  'experiences',
#  'follow',
#  'opinions',
#  'audio',
#  'training',
#  'research',
#  'company',
#  '|',
#  'quality',
#  'receipts',
#  'consumer',
#  'cognition',
#  'memory',
#  'create',
#  'contain',
#  'write',
#  'boxes',
#  'topics',
#  'answering',
#  'rate',
#  'test',
#  'earn',
#  'academic',
#  'utterance',
#  'time',
#  'recording',
#  'upload',
#  'de',
#  '02/20/20',
#  'payment',
#  'videos',
#  'help',
#  'canis',
#  'animal',
#  'categorization',
#  'un',
#  'generated',
#  'contact',
#  'personal',
#  'given',
#  'people',
#  'perceptions',
#  'study(~',
#  'work',
#  'workplace',
#  'provide',
#  'faces',
#  'phone',
#  'emotions',
#  'writing',
#  'video',
#  'label',
#  'social',
#  'media',
#  'speech',
#  'decision',
#  'possible',
#  'partner',
#  'required',
#  'transcription',
#  'webcam',
#  'required(~',
#  'life',
#  'furniture',
#  'relations',
#  'experiences(~',
#  'box',
#  'user',
#  'submit',
#  'rejected',
#  'attitudes',
#  'adult',
#  'content',
#  'paraphrase',
#  'machine',
#  'search',
#  'native',
#  'requested',
#  'qualifier',
#  'easy',
#  'stress',
#  'decisions',
#  'resolution',
#  'making',
#  'access',
#  'conversational',
#  'job',
#  'computer',
#  'evaluation',
#  'men',
#  'persuasion',
#  'good',
#  'allennlp',
#  'temporal',
#  'relationships',
#  'drawing',
#  'success',
#  'session',
#  'psychology',
#  'preferences',
#  'quick',
#  'feedback',
#  'revise',
#  'invitation',
#  'only)(~',
#  'visual']

# %%
pcaWords = sklearn.decomposition.PCA(n_components = 10).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data)

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible 
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
def normalize(vector):
    normalized_vector = vector / np.linalg.norm(vector)
    return normalized_vector

def dimension(model, positives, negatives):
    diff = sum([normalize(model[x]) for x in positives]) - sum([normalize(model[y]) for y in negatives])
    return diff

# %%
Gender = dimension(nytimes_model, ['man','him','he'], ['woman', 'her', 'she'])
Race = dimension(nytimes_model, ['black','blacks','African'], ['white', 'whites', 'Caucasian'])
Class = dimension(nytimes_model, ['rich', 'richer', 'richest', 'expensive', 'wealthy'], ['poor', 'poorer', 'poorest', 'cheap', 'inexpensive'])

# %%
Occupations = ["doctor","lawyer","plumber","scientist","hairdresser", "nanny","carpenter","entrepreneur","musician","writer", "banker","poet","nurse"]

Foods = ["steak", "bacon", "croissant", "cheesecake", "salad", "cheeseburger", "vegetables", "beer", "wine", "pastry"]

Sports  = ["basketball", "baseball", "boxing", "softball", "volleyball", "tennis", "golf", "hockey", "soccer"]

# %%
def makeDF(model, word_list):
    g = []
    r = []
    c = []
    for word in word_list:
        g.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Gender.reshape(1,-1))[0][0])
        r.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Race.reshape(1,-1))[0][0])
        c.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Class.reshape(1,-1))[0][0])
    df = pandas.DataFrame({'gender': g, 'race': r, 'class': c}, index = word_list)
    return df

# %%
OCCdf = makeDF(nytimes_model, Occupations) 
Fooddf = makeDF(nytimes_model, Foods)
Sportsdf = makeDF(nytimes_model, Sports)

# %%
def Coloring(Series):
    x = Series.values
    y = x-x.min()
    z = y/y.max()
    c = list(plt.cm.rainbow(z))
    return c

def PlotDimension(ax,df, dim):
    ax.set_frame_on(False)
    ax.set_title(dim, fontsize = 20)
    colors = Coloring(df[dim])
    for i, word in enumerate(df.index):
        ax.annotate(word, (0, df[dim][i]), color = colors[i], alpha = 0.6, fontsize = 12)
    MaxY = df[dim].max()
    MinY = df[dim].min()
    plt.ylim(MinY,MaxY)
    plt.yticks(())
    plt.xticks(())

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, OCCdf, 'gender')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, OCCdf, 'race')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, OCCdf, 'class')
plt.show()

# %% [markdown]
# You would increase the sample size if you want to do a more serious study.
#
# ## <span style="color:red">*Exercise 4a*</span>
#
# <span style="color:red">**Do only 4a or 4b.** Construct cells immediately below this that calculate the scores for a small sample of documents from outside your corpus to identify which are *closest* to your corpus. Then calculate the scores for a few phrases or sentences to identify the ones most likely to have appeared in your corpus. Interrogate patterns associated with these document/phrase scores (e.g., which companies produced job ads most or least likely to find jobseekers in the resume corpus?) What do these patterns suggest about the boundaries of your corpus?

# %%
hitsmk1DF['Reward'] = hitsmk1DF['Reward'].map(lambda x: x.lstrip('$'))
hitsmk1DF
# Out:
#                                                                                   Title  \
# Requester
# Panel                                   Extract purchased items from a shopping receipt
# Computer Vision Turk                                            Trace Object Boundaries
# Phil Maher                            "Archival Video Reviewer" Create Title Descrip...
# James Billings                                                   Market Research Survey
# Panel                                   Extract purchased items from a shopping receipt
# Bright--Side                          How do you feel when seeing a painting?(WARNIN...
# Content Research                                              Clean Up How-To Questions
# LE METAYER Baptiste                                             Find data about company
# Lei Hou                                          Paraphrase machine-generated questions
# lijuanzi                                         Paraphrase machine-generated questions
# celinachan610                                    Paraphrase machine-generated questions
# Knowledge Graph                                  Paraphrase machine-generated questions
# HYUNSUK CHUNG                         Write the words shown in an image (document) D...
# Hanna Diggins                                                  PCB Text Bounding Points
# User Surveys                                      Feature Detection Task: 15-40 Minutes
# Oliver Boyne                                                        Label dog keypoints
# Bailey O'Sullivan                                                   Contact Info Search
# William Leung                                       Is the pronunciation native enough?
# xlab research                         [4+ stars] Write rules-of-thumb for social nor...
# f8b64e4e-b7c8-47a8-9ee3-b161727f4ca2     Judge the reputation polarity of Article Clips
# Job Spotter                              Extract contact information from a hiring sign
# Jesse D. Crosson                            Congressional press release data collection
# John Smith                            Find out when an event happens based on a news...
# Shopping Receipts                                    Extract Data From Shopping Receipt
# Andrew Higginbotham                   Find the data for five personal injury lawyers...
# Justin Barnett                                   MUST BE 21+ | Collect Data From Strain
# Ian Makgill                                                         Text Classification
# Hanumant Singh                                                 Adjust 10 bounding boxes
# Analytics                                                    Find topics in given texts
# NLUResearch                                          Explain a Story regular largescale
# ...                                                                                 ...
# Better Training                                      Help Create Better Training Videos
# Better Training                                      Help Create Better Training Videos
# Better Training                                      Help Create Better Training Videos
# Better Training                                      Help Create Better Training Videos
# Christopher Asplund                   English-Turkish Sentence Comprehension Experim...
# Jessica Benson                        Memory and Cognition Study Part One (~ 25 minu...
# Serena Hagerty                                         Payment for Auction(~ 1 minutes)
# Rece Capture                                            Audit The Receipt Transcription
# Jessica Benson                        Memory and Cognition Study Part One (~ 25 minu...
# Benjamin Korman                                           Compensation HIT(~ 1 minutes)
# Benjamin Korman                                           Compensation HIT(~ 1 minutes)
# Jessica Benson                        Memory and Cognition Study Part One (~ 25 minu...
# mcoverage                               Recording Reference Using Pointing and Sentence
# duan-tajima                                                 Canis Animal Categorization
# duan-tajima                                                 Canis Animal Categorization
# duan-tajima                                                 Canis Animal Categorization
# p9r                                                                     Transcribe data
# p9r                                                                     Transcribe data
# p9r                                                                     Transcribe data
# Jessica Benson                        Memory and Cognition Study Part One (~ 25 minu...
# Svenja Wagner                                     Aprender un poco de un nuevo lenguaje
# duan-tajima                                                 Canis Animal Categorization
# Svenja Wagner                                     Aprender un poco de un nuevo lenguaje
# Svenja Wagner                                     Aprender un poco de un nuevo lenguaje
# rich hoffman                          Do these profile photos contain a real human f...
# Shopping Receipts                                    Extract Data From Shopping Receipt
# duan-tajima                                                 Canis Animal Categorization
# duan-tajima                                                 Canis Animal Categorization
# duan-tajima                                                 Canis Animal Categorization
# Shopping Receipts                                    Extract Data From Shopping Receipt
#
#                                      Reward  \
# Requester
# Panel                                 0.09
# Computer Vision Turk                  0.60
# Phil Maher                            0.01
# James Billings                        0.01
# Panel                                 0.08
# Bright--Side                          0.07
# Content Research                      0.05
# LE METAYER Baptiste                   0.03
# Lei Hou                               0.10
# lijuanzi                              0.10
# celinachan610                         0.10
# Knowledge Graph                       0.10
# HYUNSUK CHUNG                         0.02
# Hanna Diggins                         0.03
# User Surveys                          1.25
# Oliver Boyne                          0.03
# Bailey O'Sullivan                     0.03
# William Leung                         0.01
# xlab research                         0.25
# f8b64e4e-b7c8-47a8-9ee3-b161727f4ca2  0.08
# Job Spotter                           0.03
# Jesse D. Crosson                      1.10
# John Smith                            0.40
# Shopping Receipts                     0.01
# Andrew Higginbotham                   2.00
# Justin Barnett                        0.02
# Ian Makgill                           0.02
# Hanumant Singh                        0.02
# Analytics                             0.01
# NLUResearch                           1.10
# ...                                     ...
# Better Training                       5.00
# Better Training                       5.00
# Better Training                       5.00
# Better Training                       5.00
# Christopher Asplund                   1.44
# Jessica Benson                        0.75
# Serena Hagerty                        3.00
# Rece Capture                          0.01
# Jessica Benson                        0.75
# Benjamin Korman                       1.00
# Benjamin Korman                       1.00
# Jessica Benson                        0.75
# mcoverage                             0.50
# duan-tajima                           0.20
# duan-tajima                           0.20
# duan-tajima                           0.20
# p9r                                   0.05
# p9r                                   0.02
# p9r                                   0.05
# Jessica Benson                        0.75
# Svenja Wagner                         4.00
# duan-tajima                           0.20
# Svenja Wagner                         4.00
# Svenja Wagner                         4.00
# rich hoffman                          0.02
# Shopping Receipts                     0.08
# duan-tajima                           0.20
# duan-tajima                           0.20
# duan-tajima                           0.20
# Shopping Receipts                     0.01
#
#                                                                         tokenized_sents  \
# Requester
# Panel                                 [[Extract, purchased, items, from, a, shopping...
# Computer Vision Turk                                      [[Trace, Object, Boundaries]]
# Phil Maher                            [[Archival, Video, Reviewer, Create, Title, De...
# James Billings                                             [[Market, Research, Survey]]
# Panel                                 [[Extract, purchased, items, from, a, shopping...
# Bright--Side                          [[How, do, you, feel, when, seeing, a, paintin...
# Content Research                                      [[Clean, Up, How, To, Questions]]
# LE METAYER Baptiste                                      [[Find, data, about, company]]
# Lei Hou                                   [[Paraphrase, machine, generated, questions]]
# lijuanzi                                  [[Paraphrase, machine, generated, questions]]
# celinachan610                             [[Paraphrase, machine, generated, questions]]
# Knowledge Graph                           [[Paraphrase, machine, generated, questions]]
# HYUNSUK CHUNG                         [[Write, the, words, shown, in, an, image, doc...
# Hanna Diggins                                           [[PCB, Text, Bounding, Points]]
# User Surveys                              [[Feature, Detection, Task, 15, 40, Minutes]]
# Oliver Boyne                                                  [[Label, dog, keypoints]]
# Bailey O'Sullivan                                             [[Contact, Info, Search]]
# William Leung                                [[Is, the, pronunciation, native, enough]]
# xlab research                         [[4, +, stars, Write, rules, of, thumb, for, s...
# f8b64e4e-b7c8-47a8-9ee3-b161727f4ca2  [[Judge, the, reputation, polarity, of, Articl...
# Job Spotter                           [[Extract, contact, information, from, a, hiri...
# Jesse D. Crosson                      [[Congressional, press, release, data, collect...
# John Smith                            [[Find, out, when, an, event, happens, based, ...
# Shopping Receipts                            [[Extract, Data, From, Shopping, Receipt]]
# Andrew Higginbotham                   [[Find, the, data, for, five, personal, injury...
# Justin Barnett                        [[MUST, BE, 21, +, |, Collect, Data, From, Str...
# Ian Makgill                                                    [[Text, Classification]]
# Hanumant Singh                                          [[Adjust, 10, bounding, boxes]]
# Analytics                                            [[Find, topics, in, given, texts]]
# NLUResearch                                  [[Explain, a, Story, regular, largescale]]
# ...                                                                                 ...
# Better Training                              [[Help, Create, Better, Training, Videos]]
# Better Training                              [[Help, Create, Better, Training, Videos]]
# Better Training                              [[Help, Create, Better, Training, Videos]]
# Better Training                              [[Help, Create, Better, Training, Videos]]
# Christopher Asplund                   [[English, Turkish, Sentence, Comprehension, E...
# Jessica Benson                        [[Memory, and, Cognition, Study, Part, One, ~,...
# Serena Hagerty                                  [[Payment, for, Auction(~, 1, minutes]]
# Rece Capture                                     [[Audit, The, Receipt, Transcription]]
# Jessica Benson                        [[Memory, and, Cognition, Study, Part, One, ~,...
# Benjamin Korman                                     [[Compensation, HIT(~, 1, minutes]]
# Benjamin Korman                                     [[Compensation, HIT(~, 1, minutes]]
# Jessica Benson                        [[Memory, and, Cognition, Study, Part, One, ~,...
# mcoverage                             [[Recording, Reference], [Using, Pointing, and...
# duan-tajima                                           [[Canis, Animal, Categorization]]
# duan-tajima                                           [[Canis, Animal, Categorization]]
# duan-tajima                                           [[Canis, Animal, Categorization]]
# p9r                                                                [[Transcribe, data]]
# p9r                                                                [[Transcribe, data]]
# p9r                                                                [[Transcribe, data]]
# Jessica Benson                        [[Memory, and, Cognition, Study, Part, One, ~,...
# Svenja Wagner                           [[Aprender, un, poco, de, un, nuevo, lenguaje]]
# duan-tajima                                           [[Canis, Animal, Categorization]]
# Svenja Wagner                           [[Aprender, un, poco, de, un, nuevo, lenguaje]]
# Svenja Wagner                           [[Aprender, un, poco, de, un, nuevo, lenguaje]]
# rich hoffman                          [[Do, these, profile, photos, contain, a, real...
# Shopping Receipts                            [[Extract, Data, From, Shopping, Receipt]]
# duan-tajima                                           [[Canis, Animal, Categorization]]
# duan-tajima                                           [[Canis, Animal, Categorization]]
# duan-tajima                                           [[Canis, Animal, Categorization]]
# Shopping Receipts                            [[Extract, Data, From, Shopping, Receipt]]
#
#                                                                        normalized_sents
# Requester
# Panel                                  [[extract, purchased, items, shopping, receipt]]
# Computer Vision Turk                                      [[trace, object, boundaries]]
# Phil Maher                            [[archival, video, reviewer, create, title, de...
# James Billings                                             [[market, research, survey]]
# Panel                                  [[extract, purchased, items, shopping, receipt]]
# Bright--Side                          [[feel, seeing, painting?(warning, hit, contai...
# Content Research                                                   [[clean, questions]]
# LE METAYER Baptiste                                             [[find, data, company]]
# Lei Hou                                   [[paraphrase, machine, generated, questions]]
# lijuanzi                                  [[paraphrase, machine, generated, questions]]
# celinachan610                             [[paraphrase, machine, generated, questions]]
# Knowledge Graph                           [[paraphrase, machine, generated, questions]]
# HYUNSUK CHUNG                         [[write, words, shown, image, document, write,...
# Hanna Diggins                                           [[pcb, text, bounding, points]]
# User Surveys                                      [[feature, detection, task, minutes]]
# Oliver Boyne                                                  [[label, dog, keypoints]]
# Bailey O'Sullivan                                             [[contact, info, search]]
# William Leung                                                 [[pronunciation, native]]
# xlab research                         [[+, stars, write, rules, thumb, social, norms...
# f8b64e4e-b7c8-47a8-9ee3-b161727f4ca2    [[judge, reputation, polarity, article, clips]]
# Job Spotter                             [[extract, contact, information, hiring, sign]]
# Jesse D. Crosson                      [[congressional, press, release, data, collect...
# John Smith                                [[find, event, happens, based, news, report]]
# Shopping Receipts                                  [[extract, data, shopping, receipt]]
# Andrew Higginbotham                   [[find, data, personal, injury, lawyers, speci...
# Justin Barnett                                          [[+, |, collect, data, strain]]
# Ian Makgill                                                    [[text, classification]]
# Hanumant Singh                                              [[adjust, bounding, boxes]]
# Analytics                                                [[find, topics, given, texts]]
# NLUResearch                                     [[explain, story, regular, largescale]]
# ...                                                                                 ...
# Better Training                              [[help, create, better, training, videos]]
# Better Training                              [[help, create, better, training, videos]]
# Better Training                              [[help, create, better, training, videos]]
# Better Training                              [[help, create, better, training, videos]]
# Christopher Asplund                   [[english, turkish, sentence, comprehension, e...
# Jessica Benson                                 [[memory, cognition, study, ~, minutes]]
# Serena Hagerty                                          [[payment, auction(~, minutes]]
# Rece Capture                                          [[audit, receipt, transcription]]
# Jessica Benson                                 [[memory, cognition, study, ~, minutes]]
# Benjamin Korman                                        [[compensation, hit(~, minutes]]
# Benjamin Korman                                        [[compensation, hit(~, minutes]]
# Jessica Benson                                 [[memory, cognition, study, ~, minutes]]
# mcoverage                                [[recording, reference], [pointing, sentence]]
# duan-tajima                                           [[canis, animal, categorization]]
# duan-tajima                                           [[canis, animal, categorization]]
# duan-tajima                                           [[canis, animal, categorization]]
# p9r                                                                [[transcribe, data]]
# p9r                                                                [[transcribe, data]]
# p9r                                                                [[transcribe, data]]
# Jessica Benson                                 [[memory, cognition, study, ~, minutes]]
# Svenja Wagner                           [[aprender, un, poco, de, un, nuevo, lenguaje]]
# duan-tajima                                           [[canis, animal, categorization]]
# Svenja Wagner                           [[aprender, un, poco, de, un, nuevo, lenguaje]]
# Svenja Wagner                           [[aprender, un, poco, de, un, nuevo, lenguaje]]
# rich hoffman                          [[profile, photos, contain, real, human, face,...
# Shopping Receipts                                  [[extract, data, shopping, receipt]]
# duan-tajima                                           [[canis, animal, categorization]]
# duan-tajima                                           [[canis, animal, categorization]]
# duan-tajima                                           [[canis, animal, categorization]]
# Shopping Receipts                                  [[extract, data, shopping, receipt]]
#
# [877 rows x 4 columns]

# %%
hitsmk1DF.sort_values(by = 'Reward', ascending=False)[:50]
# Out:
#                                                                Title Reward  \
# Requester
# SurveyComet        Survey - webcam & audio recording required(~ 2...  8.00
# SurveyComet        Survey - webcam & audio recording required(~ 2...  8.00
# Olivier Klein                                 HIT for A1U5BE8XJRXKW3  8.00
# SurveyComet        Survey - webcam & audio recording required(~ 2...  8.00
# SurveyComet        Survey - webcam & audio recording required(~ 2...  8.00
# SurveyComet        Survey - webcam & audio recording required(~ 2...  8.00
# Olivier Klein                                 HIT for A1U3UUELW55W65  8.00
# SurveyComet        Survey - webcam & audio recording required(~ 2...  8.00
# Empirical Jury                         Compensation HIT(~ 1 minutes)  6.75
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Allen NLP          AllenNLP: Question-Answering on Temporal Relat...  6.00
# Allen NLP          AllenNLP: Question-Answering on Temporal Relat...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Allen NLP          AllenNLP: Question-Answering on Temporal Relat...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
# Matthew Gallagher  Mental Health and Well-being in Veterans (ages...  6.00
#
#                                                      tokenized_sents  \
# Requester
# SurveyComet        [[Survey, webcam, audio, recording, required(~...
# SurveyComet        [[Survey, webcam, audio, recording, required(~...
# Olivier Klein                           [[HIT, for, A1U5BE8XJRXKW3]]
# SurveyComet        [[Survey, webcam, audio, recording, required(~...
# SurveyComet        [[Survey, webcam, audio, recording, required(~...
# SurveyComet        [[Survey, webcam, audio, recording, required(~...
# Olivier Klein                           [[HIT, for, A1U3UUELW55W65]]
# SurveyComet        [[Survey, webcam, audio, recording, required(~...
# Empirical Jury                   [[Compensation, HIT(~, 1, minutes]]
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Allen NLP          [[AllenNLP, Question, Answering, on, Temporal,...
# Allen NLP          [[AllenNLP, Question, Answering, on, Temporal,...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Allen NLP          [[AllenNLP, Question, Answering, on, Temporal,...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
# Matthew Gallagher  [[Mental, Health, and, Well, being, in, Vetera...
#
#                                                     normalized_sents
# Requester
# SurveyComet        [[survey, webcam, audio, recording, required(~...
# SurveyComet        [[survey, webcam, audio, recording, required(~...
# Olivier Klein                                [[hit, a1u5be8xjrxkw3]]
# SurveyComet        [[survey, webcam, audio, recording, required(~...
# SurveyComet        [[survey, webcam, audio, recording, required(~...
# SurveyComet        [[survey, webcam, audio, recording, required(~...
# Olivier Klein                                [[hit, a1u3uuelw55w65]]
# SurveyComet        [[survey, webcam, audio, recording, required(~...
# Empirical Jury                      [[compensation, hit(~, minutes]]
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Allen NLP          [[allennlp, question, answering, temporal, rel...
# Allen NLP          [[allennlp, question, answering, temporal, rel...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Allen NLP          [[allennlp, question, answering, temporal, rel...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...
# Matthew Gallagher  [[mental, health, veterans, ages, 65)(~, minut...

# %% [markdown]
# From these results we can see that many of the highest-paying HITs are surveys.  This is significant given the role of survey HITs in the aforementioned hypothesis on personal data extraction.  It reveals that suryeys targeting Workers for their personal data are highly valuable sources of information for Requesters.

# %% [markdown]
# ## <span style="color:red">*Exercise 4b*</span>
#
# <span style="color:red">**Do only 4a or 4b.** Construct cells immediately below this that align word embeddings over time or across domains/corpora. Interrogate the spaces that result and ask which words changed most and least over the entire period or between contexts/corpora. What does this reveal about the social game underlying your space?
